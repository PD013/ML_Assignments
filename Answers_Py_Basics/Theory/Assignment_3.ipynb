# %% [markdown]
# # **1. Why are functions advantageous to have in your programs?**

# %% [markdown]
# Functions in programs are advantageous to due to its property of resuabiliy and its Modularity also making your code neater, easier to understand, and letting you use the same code again in different parts of our program

# %% [markdown]
# # **2. When does the code in a function run: when it's specified or when it's called?**

# %% [markdown]
# The code in a function runs when it's called.

# %% [markdown]
# # **3. What statement creates a function?**

# %% [markdown]
# def statement

# %% [markdown]
# # **4. What is the difference between a function and a function call?**

# %% [markdown]
# A function is a piece of code which enhances reusability and modularity of your program. It means that piece of code need not be written again. A function call means invoking or calling that function. Unless a function is called there is no use of that function

# %% [markdown]
# # **5. How many global scopes are there in a Python program? How many local scopes?**

# %% [markdown]
# There is Only one global scope and there can be as many as local scope because its inside a function so Each function creates its own local scope

# %% [markdown]
# # **6. What happens to variables in a local scope when the function call returns?**

# %% [markdown]
# When a function call returns the variables in its local scope are destroyed or cleaned up.

# %% [markdown]
# # **7. What is the concept of a return value? Is it possible to have a return value in an expression?**

# %% [markdown]
# A return value is what a function gives back when it's used. It's like a result that you can use just like any other value in your code, for calculations or assignments.

# %% [markdown]
# # **8. If a function does not have a return statement, what is the return value of a call to that function?**

# %% [markdown]
# If a function does not have a return statement, the return value of a call to that function is `None.`

# %% [markdown]
# # **9. How do you make a function variable refer to the global variable?**

# %% [markdown]
# To make a function variable refer to the global variable, you need to use the `global` before stating that variable inside a function

# %% [markdown]
# # **10. What is the data type of None?**

# %% [markdown]
# The data type of None in Python is called `NoneType`.

# %% [markdown]
# # **11. What does the sentence import areallyourpetsnamederic do?**

# %% [markdown]
# That import statement imports a module named `areallyourpetsnamederic`

# %% [markdown]
# # **12. If you had a bacon() feature in a spam module, what would you call it after importing spam?**

# %% [markdown]
# Would be called `spam.bacon()`

# %% [markdown]
# # **13. What can you do to save a programme from crashing if it encounters an error?**

# %% [markdown]
# Place the error causing line in the try block and state use except block to handle the error.

# %% [markdown]
# # **14. What is the purpose of the try clause? What is the purpose of the except clause?**

# %% [markdown]
# The purpose of Try block is to handle any problem causing part of program and if any issue come then donot affect other parts and not led to program disruption/crash and Except is used as direction to handle any problem if arise in the try block
